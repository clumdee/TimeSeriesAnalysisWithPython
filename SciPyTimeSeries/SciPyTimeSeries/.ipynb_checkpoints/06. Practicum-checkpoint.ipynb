# %% [markdown]
# ### Let's find some time series data
# hint: http://pandas.pydata.org/pandas-docs/stable/remote_data.html

# %%
# %matplotlib inline 
import matplotlib.pylab
import numpy as np
import pandas as pd

import pandas_datareader.data as web

# %%
start = pd.Timestamp('2010-1-1')
end = pd.Timestamp('2013-1-27')
f = web.DataReader("F", 'google', start, end)

# %%
f.head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2010-01-04  10.17  10.28  10.05  10.28   60855796
# 2010-01-05  10.45  11.24  10.40  10.96  215620138
# 2010-01-06  11.21  11.46  11.13  11.37  200070554
# 2010-01-07  11.46  11.69  11.32  11.66  130201626
# 2010-01-08  11.67  11.74  11.46  11.69  130462912

# %% [markdown]
# ### Plot the high and low values of Google's stock for July and August 2012

# %%
# %load snippets/prac1.py

# %%
a = [5,6,7,8,9]
b = ['aa','bb','cc']
c = pd.DataFrame(np.random.rand(5,3), index=a,columns=b)
c
# Out:
#          aa        bb        cc
# 5  0.225475  0.985336  0.394629
# 6  0.828477  0.895968  0.894465
# 7  0.984107  0.413379  0.960787
# 8  0.817845  0.710170  0.028758
# 9  0.031622  0.789349  0.340731

# %%
c.loc[6:8].bb
# Out:
# 6    0.895968
# 7    0.413379
# 8    0.710170
# Name: bb, dtype: float64

# %%
f.loc['2012-07-31']
# Out:
# Open             9.13
# High             9.28
# Low              9.12
# Close            9.24
# Volume    41384782.00
# Name: 2012-07-31 00:00:00, dtype: float64

# %%
f['2012-07-31':'2012-07-31']
# Out:
#             Open  High   Low  Close    Volume
# Date
# 2012-07-31  9.13  9.28  9.12   9.24  41384782

# %%
f['2012-07':'2012-08'][['High','Low']].plot()

# %% [markdown]
# ### Is the variance of the trading volume relatively stable over time?

# %%
# %load snippets/prac2.py

# %%
f['Volume'].rolling(50).var().plot()

# %% [markdown]
# ### Is the expanding window variance of the trading volume relatively stable over time?

# %%
# %load snippets/prac3.py

# %%
f['Volume'].expanding().var().plot()

# %% [markdown]
# ### On how many days did the stock close higher than it opened?
#
# Hint: check out .tshift() in the pandas docs
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#shifting-lagging

# %%
# %load snippets/prac4.py
lagged = f.shift(1)
print(sum((f - lagged)['Open'] > 0))

f['DayGain'] = f['Open'] - lagged['Open']
print(sum(f['DayGain'] > 0)/len(f['DayGain']))
# Out:
# 382
# 0.495460440986

# %%
# f[f['Close']>f['Open']].count()
sum(f['Close']>f['Open'])
# Out:
# 350

# %% [markdown]
# ### And did the 'up' days become more or less frequent over time?

# %%
# %load snippets/prac5.py

# %%
f['DayGain'].rolling(20).mean().plot()

# %%
(f['Close']>f['Open']).rolling(20).mean().plot()

# %% [markdown]
# ### Compute and plot the mean monthly High value of the stock

# %%
# %load snippets/prac6.py

# %%
f['High'].resample('M').mean().plot()

# %% [markdown]
# ### Explore the variance of the differenced volume

# %%
# %load snippets/prac7.py

# %%
f['Volume'][-5:]
# Out:
# Date
# 2013-01-18    45726597
# 2013-01-22    35475103
# 2013-01-23    58122134
# 2013-01-24    42536100
# 2013-01-25    53405308
# Name: Volume, dtype: int64

# %%
f['Volume'].shift(1)[-5:]
# Out:
# Date
# 2013-01-18    44299777.0
# 2013-01-22    45726597.0
# 2013-01-23    35475103.0
# 2013-01-24    58122134.0
# 2013-01-25    42536100.0
# Name: Volume, dtype: float64

# %%
vol_diff = f['Volume']-f['Volume'].shift(1)
vol_diff.rolling(20).var().plot()

# %% [markdown]
# ### Does the lagged time series correlate with itself?

# %%
# %load snippets/prac8.py
# What's the best predictor of tomorrow's stock price?

# %%
pd.DataFrame({'real':f.Volume, 'lag':f.Volume.shift(1)}).corr()
# Out:
#            lag      real
# lag   1.000000  0.649776
# real  0.649776  1.000000
