# %%
# %matplotlib inline
import matplotlib.pylab

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # The special thing about time series is that data points relate to one another...they are not independent
# So we can to compare them and relate them. One way to do this is to look at how they change. For example, we can 'difference' a time series

# %%
ts = pd.Series(np.random.randn(20), pd.date_range('7/1/16', 
                                                  freq = 'D', 
                                                  periods = 20))
ts_lagged = ts.shift()

# %%
type(ts.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Query: how can I shift my time series 'back' instead of forward?

# %%
# %load snippets/shift_future.py
ts_led = ts.shift(-1)

# %%
plt.plot(ts, color = 'blue')
plt.plot(ts_lagged, color = 'red')
plt.plot(ts_led, color = 'green')

# %% [markdown]
# # Window functions give you moving aggregate measures of a time series

# %%
# Window functions are like aggregation functions
# You can use them in conjunction with .resample()

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('5/1/2016', freq = 'D', periods = 600), columns = ['A', 'B', 'C'])
df.head()
# Out:
#                    A         B         C
# 2016-05-01  0.199883  1.104796 -0.039272
# 2016-05-02 -1.128149  0.006182 -1.848433
# 2016-05-03 -0.692614 -1.739206  0.838344
# 2016-05-04  0.414503 -0.070672 -1.900017
# 2016-05-05  2.255133  0.755341 -0.519229

# %%
# define a rolling window to be called
r = df.rolling(window = 20)

# %%
df['A'].plot(color = 'gray')
r.mean()['A'].plot(color = 'red', marker='x')

# this is equivalent to defining r==rolling and then plot r.mean() above
df.rolling(window = 20)['A'].mean().plot(color = 'green')
# Select the column first then roll or roll first then pick a column
df['A'].rolling(window = 20).mean().plot(color = 'yellow')

# %% [markdown]
# ### Try out some of these options with .rolling()
#
# r.agg, r.apply, r.count, r.max, r.median, r.name, r.quantile, r.kurt,
# r.aggregate, r.std, r.skew, r.sum, r.var

# %%
# 'agg' create a dataframe with a higher dimension
temp = df.rolling(window = 3).agg(['max','min','mean']).head()
temp
# Out:
#                    A                             B                      \
#                  max       min      mean       max       min      mean
# 2016-05-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-05-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-05-03  0.199883 -1.128149 -0.540293  1.104796 -1.739206 -0.209409
# 2016-05-04  0.414503 -1.128149 -0.468753  0.006182 -1.739206 -0.601232
# 2016-05-05  2.255133 -0.692614  0.659007  0.755341 -1.739206 -0.351512
#
#                    C
#                  max       min      mean
# 2016-05-01       NaN       NaN       NaN
# 2016-05-02       NaN       NaN       NaN
# 2016-05-03  0.838344 -1.848433 -0.349787
# 2016-05-04  0.838344 -1.900017 -0.970035
# 2016-05-05  0.838344 -1.900017 -0.526968

# %%
# accessing data from a dataframe with higher dimensions
temp['A']['max']
# Out:
# 2016-05-01         NaN
# 2016-05-02         NaN
# 2016-05-03    0.199883
# 2016-05-04    0.414503
# 2016-05-05    2.255133
# Freq: D, Name: max, dtype: float64

# %%
# create an aggreate set of data with 'agg' == 'aggregate'
df['A'].rolling(window = 20).agg(['max','min','mean']).plot()
df['A'].rolling(window = 20).quantile(0.25).plot(label='Q0.25')
plt.legend()

# %% [markdown]
# ### What about a custom function?

# %%
df[0:9]
# Out:
#                    A         B         C
# 2016-05-01  0.199883  1.104796 -0.039272
# 2016-05-02 -1.128149  0.006182 -1.848433
# 2016-05-03 -0.692614 -1.739206  0.838344
# 2016-05-04  0.414503 -0.070672 -1.900017
# 2016-05-05  2.255133  0.755341 -0.519229
# 2016-05-06 -1.206867 -0.527899 -4.264640
# 2016-05-07  0.608347  0.068844  0.532830
# 2016-05-08 -1.322015 -1.188496 -2.485511
# 2016-05-09  0.627110 -1.446902 -0.267472

# %%
# shift the dataframe with a moving window
df.rolling(window = 5, center = False).apply(lambda x: x[0])[0:9]
# Out:
#                    A         B         C
# 2016-05-01       NaN       NaN       NaN
# 2016-05-02       NaN       NaN       NaN
# 2016-05-03       NaN       NaN       NaN
# 2016-05-04       NaN       NaN       NaN
# 2016-05-05  0.199883  1.104796 -0.039272
# 2016-05-06 -1.128149  0.006182 -1.848433
# 2016-05-07 -0.692614 -1.739206  0.838344
# 2016-05-08  0.414503 -0.070672 -1.900017
# 2016-05-09  2.255133  0.755341 -0.519229

# %%
# %load snippets/custom_rolling.py
# shift the dataframe and performation a division
df.rolling(window = 5, center = False).apply(lambda x: x[0]/x[1])[0:9]
# Out:
#                    A           B         C
# 2016-05-01       NaN         NaN       NaN
# 2016-05-02       NaN         NaN       NaN
# 2016-05-03       NaN         NaN       NaN
# 2016-05-04       NaN         NaN       NaN
# 2016-05-05 -0.177178  178.720527  0.021246
# 2016-05-06  1.628828   -0.003554 -2.204862
# 2016-05-07 -1.670950   24.609666 -0.441230
# 2016-05-08  0.183804   -0.093563  3.659304
# 2016-05-09 -1.868585   -1.430843  0.121752

# %% [markdown]
# ### What if I want to generate a rolling window function of monthly data from daily data?

# %%
# %load snippets/resample_rolling.py

# %%
ts_long = pd.Series(np.random.randn(200), pd.date_range('7/1/16', freq = 'D', periods = 200))
# ts_long.resample('M').apply(lambda x: len(x))
ts_long.resample('M').count()
# Out:
# 2016-07-31    31
# 2016-08-31    31
# 2016-09-30    30
# 2016-10-31    31
# 2016-11-30    30
# 2016-12-31    31
# 2017-01-31    16
# Freq: M, dtype: int64

# %%
ts_long.resample('M').mean().plot(color='blue')
ts_long.resample('M').mean().rolling(window = 3).mean().plot(color='red')

# %% [markdown]
# ## Expanding windows

# %%
df.head()
# Out:
#                    A         B         C
# 2016-05-01  0.199883  1.104796 -0.039272
# 2016-05-02 -1.128149  0.006182 -1.848433
# 2016-05-03 -0.692614 -1.739206  0.838344
# 2016-05-04  0.414503 -0.070672 -1.900017
# 2016-05-05  2.255133  0.755341 -0.519229

# %%
# expanding == increasing the window interval along a series/dataframe
# e.g. df['A'][2] = df['A'][0] + df['A'][1] + df['A'][2]
df.expanding(min_periods = 1).sum()[0:5]
# Out:
#                    A         B         C
# 2016-05-01  0.199883  1.104796 -0.039272
# 2016-05-02 -0.928266  1.110978 -1.887705
# 2016-05-03 -1.620879 -0.628228 -1.049361
# 2016-05-04 -1.206376 -0.698900 -2.949378
# 2016-05-05  1.048757  0.056441 -3.468607

# %%
df.expanding(min_periods = 1).mean()[0:5]
# Out:
#                    A         B         C
# 2016-05-01  0.199883  1.104796 -0.039272
# 2016-05-02 -0.464133  0.555489 -0.943852
# 2016-05-03 -0.540293 -0.209409 -0.349787
# 2016-05-04 -0.301594 -0.174725 -0.737344
# 2016-05-05  0.209751  0.011288 -0.693721

# %%
df.plot()
df.expanding(min_periods = 1).mean().plot()

# %% [markdown]
# # Try

# %% [markdown]
# (1) How can you perform an exponentially weight moving average rather than a window function? (hint: look for ewma + pandas docs)
#
# (2) When would you use an expanding window vs. a rolling window?
#
# (3) Write a custom function to assign .quantile(.5) function for a rolling window
#
# (4) How would you compute more than one aggregation function on a moving window function at the same time?

# %%
# %load snippets/window_funcs_try.py
#1
ts = pd.Series(np.random.randn(1000), index = pd.date_range(start = '1/1/16', periods = 1000, freq = 'D'))
ts.ewm(span = 60, freq = 'D', min_periods = 0, adjust = True).mean().plot(label='ewa')
ts.rolling(window = 60).mean().plot(label='rolling')
plt.legend()

#2 
# To get a more reliable statistic if it makes logical sense

#3
r = df.rolling(window = 3)
r.apply(lambda x: sorted(x)[round(len(x)*.5)]).head()

#4
r = df.rolling(window = 3)
r.agg(['sum', 'count']).head()
# Out:
#                    A               B               C
#                  sum count       sum count       sum count
# 2016-05-01       NaN   1.0       NaN   1.0       NaN   1.0
# 2016-05-02       NaN   2.0       NaN   2.0       NaN   2.0
# 2016-05-03 -1.620879   3.0 -0.628228   3.0 -1.049361   3.0
# 2016-05-04 -1.406260   3.0 -1.803696   3.0 -2.910106   3.0
# 2016-05-05  1.977022   3.0 -1.054536   3.0 -1.580903   3.0
